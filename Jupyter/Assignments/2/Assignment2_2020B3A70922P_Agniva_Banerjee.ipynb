# %%
import pandas as pd
df=pd.read_excel("200participantcollecteddata.xlsx",usecols=['Gender','Height (cm) (average of 3 measurments)'])

# %%
df2=df.rename(columns={'Height (cm) (average of 3 measurments)' : 'Height'})
#df
df2
# Out:
#      Gender      Height
# 0      Male  174.000000
# 1      Male  202.000000
# 2      Male  182.333333
# 3      Male  184.000000
# 4      Male  180.666667
# ..      ...         ...
# 195  Female  164.000000
# 196    Male  172.000000
# 197    Male  174.000000
# 198    Male  174.666667
# 199  Female  165.000000
#
# [200 rows x 2 columns]

# %%
df=df.replace('male','Male')
df2=df2.replace('male','Male')

# %%
df.iloc[89:95]
# Out:
#     Gender  Height (cm) (average of 3 measurments)
# 89    Male                              177.000000
# 90    Male                              193.000000
# 91    Male                              172.333333
# 92  Female                              169.333333
# 93    Male                              183.666667
# 94    Male                              170.000000

# %%
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
g = sns.histplot( x='Height', hue='Gender' , data=df2)
sns.move_legend(g,"upper right")

# %%
h=sns.boxplot(y='Height' , x='Gender' , data=df2 )

# %%
h=sns.violinplot(x='Height' , y="Gender", data=df2 , hue='Gender' )
sns.move_legend(h,"bottom right")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[14], line 2
#       1 h=sns.violinplot(x='Height' , y="Gender", data=df2 , hue='Gender' )
# ----> 2 sns.move_legend(h,"bottom right")
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\utils.py:482, in move_legend(obj, loc, **kwargs)
#     480 props.update(kwargs)
#     481 old_legend.remove()
# --> 482 new_legend = legend_func(handles, labels, loc=loc, **props)
#     483 new_legend.set_title(title.get_text(), title.get_fontproperties())
#     485 # Let the Grid object continue to track the correct legend object
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\matplotlib\axes\_axes.py:318, in Axes.legend(self, *args, **kwargs)
#     316 if len(extra_args):
#     317     raise TypeError('legend only accepts two non-keyword arguments')
# ...
